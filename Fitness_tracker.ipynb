# %% [markdown]
# <a href="https://colab.research.google.com/github/HammayalRamzan/Fitness_tracker/blob/main/Fitness_tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install Packages
# !pip install -qU langchain-pinecone langchain-google-genai
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pinecone-client 5.0.1 requires pinecone-plugin-inference<2.0.0,>=1.0.3, but you have pinecone-plugin-inference 3.1.0 which is incompatible.

# %%
# !pip install -qU langchain-community

# %%
from google.colab import userdata
from pinecone import Pinecone, ServerlessSpec

pinecone_api_key = userdata.get("PINECONE_API_KEY")

pc = Pinecone(api_key=pinecone_api_key)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.document_loaders import CSVLoader

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path="/content/fitness_tracker.csv")
data = loader.load()

# %%
loader = CSVLoader(
    file_path="/content/fitness_tracker.csv",
    csv_args={
        "delimiter": ",",
        "quotechar": '"',
        "fieldnames": ["MLB Team", "Payroll in millions", "Wins"],
    },
)

data = loader.load()
print(data)
# Out:
# [Document(metadata={'source': '/content/fitness_tracker.csv', 'row': 0}, page_content='MLB Team: User ID\nPayroll in millions: Daily Steps\nWins: Calories Burned\nNone: Hours of Sleep,Recommended Activity'), Document(metadata={'source': '/content/fitness_tracker.csv', 'row': 1}, page_content='MLB Team: User 1\nPayroll in millions: 5100\nWins: 1550\nNone: 7,Activity 1, Activity 2'), Document(metadata={'source': '/content/fitness_tracker.csv', 'row': 2}, page_content='MLB Team: User 2\nPayroll in millions: 5200\nWins: 1600\nNone: 8,Activity 2, Activity 3'), Document(metadata={'source': '/content/fitness_tracker.csv', 'row': 3}, page_content='MLB Team: User 3\nPayroll in millions: 5300\nWins: 1650\nNone: 6,Activity 3, Activity 4'), Document(metadata={'source': '/content/fitness_tracker.csv', 'row': 4}, page_content='MLB Team: User 4\nPayroll in millions: 5400\nWins: 1700\nNone: 7,Activity 4, Activity 0'), Document(metadata={'source': '/content/fitness_tracker.csv', 'row': 5}, page_conte
# ...

# %%
# !pip install -qU unstructured

# %%
from langchain_community.document_loaders.csv_loader import UnstructuredCSVLoader

loader = UnstructuredCSVLoader(
    file_path="/content/fitness_tracker.csv" , mode="elements"
)
docs = loader.load()

print(docs[0].page_content)
# Out:
# User ID Daily Steps Calories Burned Hours of Sleep Recommended Activity User 1 5100 1550 7 Activity 1, Activity 2 User 2 5200 1600 8 Activity 2, Activity 3 User 3 5300 1650 6 Activity 3, Activity 4 User 4 5400 1700 7 Activity 4, Activity 0 User 5 5500 1750 8 Activity 0, Activity 1 User 6 5600 1800 6 Activity 1, Activity 2 User 7 5700 1850 7 Activity 2, Activity 3 User 8 5800 1900 8 Activity 3, Activity 4 User 9 5900 1950 6 Activity 4, Activity 0 User 10 6000 2000 7 Activity 0, Activity 1 User 11 6100 2050 8 Activity 1, Activity 2 User 12 6200 2100 6 Activity 2, Activity 3 User 13 6300 2150 7 Activity 3, Activity 4 User 14 6400 2200 8 Activity 4, Activity 0 User 15 6500 2250 6 Activity 0, Activity 1 User 16 6600 2300 7 Activity 1, Activity 2 User 17 6700 2350 8 Activity 2, Activity 3 User 18 6800 2400 6 Activity 3, Activity 4 User 19 6900 2450 7 Activity 4, Activity 0 User 20 7000 2500 8 Activity 0, Activity 1 User 21 7100 2550 6 Activity 1, Activity 2 User 22 7200 2600 7 Activity 2, 
# ...
